# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
ITEMS = "data/items.csv"
ITEM_CATEGORIES = "data/item_categories.csv"
SALES_TRAIN_V2 = "data/sales_train_v2.csv"
SHOPS = "data/shops.csv"
SAMPLE_SUBMISSION = "data/sample_submission.csv"
TEST = "data/test.csv"
OUTPUT = "output"

# %%
# Dev dataset
sales_train = pd.read_csv(SALES_TRAIN_V2)

# Common data
items = pd.read_csv(ITEMS)
item_categories = pd.read_csv(ITEM_CATEGORIES)
shops = pd.read_csv(SHOPS)

# Test & sample
sample_submission = pd.read_csv(SAMPLE_SUBMISSION)
test = pd.read_csv(TEST)

# %% [markdown]
# ## Item category, item name

# %%
sale_train_extended = sales_train.join(items.set_index("item_id"), on="item_id")

# %%
test_extended = test.join(items.set_index("item_id"), on="item_id")

# %% [markdown]
# ## Category stats

# %%
# Total number of items sold by category
total_cat_items = sale_train_extended.groupby("item_category_id").sum()[['item_cnt_day']]
total_cat_items.columns = ["total_cat_cnt"]
sale_train_extended = sale_train_extended.join(total_cat_items, on="item_category_id")

# %%
total_cat_items = sale_train_extended.groupby("item_category_id").sum()[['item_cnt_day']]
total_cat_items.columns = ["total_cat_cnt"]
test_extended = test_extended.join(total_cat_items, on="item_category_id")

# %%
# Min number of items sold by category
min_cat_items = sale_train_extended.groupby("item_category_id").min()[['item_cnt_day']]
min_cat_items.columns = ["min_cat_cnt"]
sale_train_extended = sale_train_extended.join(min_cat_items, on="item_category_id")

# %%
min_cat_items = sale_train_extended.groupby("item_category_id").min()[['item_cnt_day']]
min_cat_items.columns = ["min_cat_cnt"]
test_extended = test_extended.join(min_cat_items, on="item_category_id")

# %%
# Max number of items sold by category
max_cat_items = sale_train_extended.groupby("item_category_id").max()[['item_cnt_day']]
max_cat_items.columns = ["max_cat_cnt"]
sale_train_extended = sale_train_extended.join(max_cat_items, on="item_category_id")

# %%
max_cat_items = sale_train_extended.groupby("item_category_id").max()[['item_cnt_day']]
max_cat_items.columns = ["max_cat_cnt"]
test_extended = test_extended.join(max_cat_items, on="item_category_id")

# %%
# Mean number of items sold by category
mean_cat_items = sale_train_extended.groupby("item_category_id").mean()[['item_cnt_day']]
mean_cat_items.columns = ["mean_cat_cnt"]
sale_train_extended = sale_train_extended.join(mean_cat_items, on="item_category_id")

# %%
mean_cat_items = sale_train_extended.groupby("item_category_id").mean()[['item_cnt_day']]
mean_cat_items.columns = ["mean_cat_cnt"]
test_extended = test_extended.join(mean_cat_items, on="item_category_id")

# %%
# Std dev of items sold by category
std_cat_items = sale_train_extended.groupby("item_category_id").std()[['item_cnt_day']]
std_cat_items.columns = ["std_cat_cnt"]
sale_train_extended = sale_train_extended.join(std_cat_items, on="item_category_id")

# %%
std_cat_items = sale_train_extended.groupby("item_category_id").std()[['item_cnt_day']]
std_cat_items.columns = ["std_cat_cnt"]
test_extended = test_extended.join(std_cat_items, on="item_category_id")

# %%
# Min price of items sold by category
min_cat_price = sale_train_extended.groupby("item_category_id").min()[['item_price']]
min_cat_price.columns = ["min_cat_price"]
sale_train_extended = sale_train_extended.join(min_cat_price, on="item_category_id")

# %%
min_cat_price = sale_train_extended.groupby("item_category_id").min()[['item_price']]
min_cat_price.columns = ["min_cat_price"]
test_extended = test_extended.join(min_cat_price, on="item_category_id")

# %%
# Max price of items sold by category
max_cat_price = sale_train_extended.groupby("item_category_id").max()[['item_price']]
max_cat_price.columns = ["max_cat_price"]
sale_train_extended = sale_train_extended.join(max_cat_price, on="item_category_id")

# %%
max_cat_price = sale_train_extended.groupby("item_category_id").max()[['item_price']]
max_cat_price.columns = ["max_cat_price"]
test_extended = test_extended.join(max_cat_price, on="item_category_id")

# %%
# Mean price of items sold by category
mean_cat_price = sale_train_extended.groupby("item_category_id").mean()[['item_price']]
mean_cat_price.columns = ["mean_cat_price"]
sale_train_extended = sale_train_extended.join(mean_cat_price, on="item_category_id")

# %%
mean_cat_price = sale_train_extended.groupby("item_category_id").mean()[['item_price']]
mean_cat_price.columns = ["mean_cat_price"]
test_extended = test_extended.join(mean_cat_price, on="item_category_id")

# %%
#sale_train_extended = sale_train_extended.drop("std_cat_price", axis=1)

# %%
std_cat_price = sale_train_extended.groupby("item_category_id").std()[['item_price']]
std_cat_price.columns = ["std_cat_price"]
sale_train_extended = sale_train_extended.join(std_cat_price, on="item_category_id")

# %%
std_cat_price = sale_train_extended.groupby("item_category_id").std()[['item_price']]
std_cat_price.columns = ["std_cat_price"]
test_extended = test_extended.join(std_cat_price, on="item_category_id")

# %% [markdown]
# ## Shop stats

# %%
# Total number of items sold in the given shop
total_shop_items = sale_train_extended.groupby("shop_id").sum()[['item_cnt_day']]
total_shop_items.columns = ["total_shop_cnt"]
sale_train_extended = sale_train_extended.join(total_shop_items, on="item_category_id")

# %%
total_shop_items = sale_train_extended.groupby("shop_id").sum()[['item_cnt_day']]
total_shop_items.columns = ["total_shop_cnt"]
test_extended = test_extended.join(total_shop_items, on="item_category_id")

# %%
# Min number of items sold in the given shop
min_shop_cnt = sale_train_extended.groupby("shop_id").min()[['item_cnt_day']]
min_shop_cnt.columns = ["min_shop_cnt"]
sale_train_extended = sale_train_extended.join(min_shop_cnt, on="item_category_id")

# %%
min_shop_cnt = sale_train_extended.groupby("shop_id").min()[['item_cnt_day']]
min_shop_cnt.columns = ["min_shop_cnt"]
test_extended = test_extended.join(min_shop_cnt, on="item_category_id")

# %%
# Max number of items sold in the given shop
max_shop_cnt = sale_train_extended.groupby("shop_id").max()[['item_cnt_day']]
max_shop_cnt.columns = ["max_shop_cnt"]
sale_train_extended = sale_train_extended.join(max_shop_cnt, on="item_category_id")

# %%
max_shop_cnt = sale_train_extended.groupby("shop_id").max()[['item_cnt_day']]
max_shop_cnt.columns = ["max_shop_cnt"]
test_extended = test_extended.join(max_shop_cnt, on="item_category_id")

# %%
#sale_train_extended = sale_train_extended.drop("max_shop_cnt", axis=1)
#test_extended = test_extended.drop("max_shop_cnt", axis=1)

# %%
# Mean number of items sold in the given shop
mean_shop_cnt = sale_train_extended.groupby("shop_id").mean()[['item_cnt_day']]
mean_shop_cnt.columns = ["mean_shop_cnt"]
sale_train_extended = sale_train_extended.join(mean_shop_cnt, on="item_category_id")

# %%
mean_shop_cnt = sale_train_extended.groupby("shop_id").mean()[['item_cnt_day']]
mean_shop_cnt.columns = ["mean_shop_cnt"]
test_extended = test_extended.join(mean_shop_cnt, on="item_category_id")

# %%
# Std
std_shop_cnt = sale_train_extended.groupby("shop_id").std()[['item_cnt_day']]
std_shop_cnt.columns = ["std_shop_cnt"]
sale_train_extended = sale_train_extended.join(std_shop_cnt, on="item_category_id")

# %%
std_shop_cnt = sale_train_extended.groupby("shop_id").std()[['item_cnt_day']]
std_shop_cnt.columns = ["std_shop_cnt"]
test_extended = test_extended.join(std_shop_cnt, on="item_category_id")

# %%
# Min price of items sold by category
min_shop_price = sale_train_extended.groupby("shop_id").min()[['item_price']]
min_shop_price.columns = ["min_shop_price"]
sale_train_extended = sale_train_extended.join(min_shop_price, on="item_category_id")

# %%
min_shop_price = sale_train_extended.groupby("shop_id").min()[['item_price']]
min_shop_price.columns = ["min_shop_price"]
test_extended = test_extended.join(min_shop_price, on="item_category_id")

# %%
# sale_train_extended = sale_train_extended.drop("max_shop_price", axis=1)
# test_extended = test_extended.drop("max_shop_price", axis=1)

# %%
# Max price of items sold by category
max_shop_price = sale_train_extended.groupby("shop_id").max()[['item_price']]
max_shop_price.columns = ["max_shop_price"]
sale_train_extended = sale_train_extended.join(max_shop_price, on="item_category_id")

# %%
max_shop_price = sale_train_extended.groupby("shop_id").max()[['item_price']]
max_shop_price.columns = ["max_shop_price"]
test_extended = test_extended.join(max_shop_price, on="item_category_id")

# %%
# Mean price of items sold by category
mean_shop_price = sale_train_extended.groupby("shop_id").mean()[['item_price']]
mean_shop_price.columns = ["mean_shop_price"]
sale_train_extended = sale_train_extended.join(mean_shop_price, on="item_category_id")

# %%
mean_shop_price = sale_train_extended.groupby("shop_id").mean()[['item_price']]
mean_shop_price.columns = ["mean_shop_price"]
test_extended = test_extended.join(mean_shop_price, on="item_category_id")

# %%
# Std price of items sold by category
std_shop_price = sale_train_extended.groupby("shop_id").std()[['item_price']]
std_shop_price.columns = ["std_shop_price"]
sale_train_extended = sale_train_extended.join(std_shop_price, on="item_category_id")

# %%
std_shop_price = sale_train_extended.groupby("shop_id").std()[['item_price']]
std_shop_price.columns = ["std_shop_price"]
test_extended = test_extended.join(std_shop_price, on="item_category_id")

# %%
sale_train_extended
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# 5        10.01.2013               0       25     2564      349.00
# 6        02.01.2013               0       25     2565      549.00
# 7        04.01.2013               0       25     2572      239.00
# 8        11.01.2013               0       25     2572      299.00
# 9        03.01.2013               0       25     2573      299.00
# 10       03.01.2013               0       25     2574      399.00
# 11       05.01.2013               0       25     2574      399.00
# 12       07.01.2013               0       25     2574      399.00
# 13       08.01.2013               0       25     2574      399.00
# 14       10.01.2013               0       25     2574      399.00
# 15       11.01.2013               0       25     2574      399.00
# 16       13.01.2013               0       25     2574      399.00
# 17       16.01.2013               0       25     2574      399.00
# 18       26.01.2013               0       25     2574      399.00
# 19       27.01.2013               0       25     2574      399.00
# 20       09.01.2013               0       25     2593      279.00
# 21       16.01.2013               0       25     2604      299.00
# 22       27.01.2013               0       25     2604      299.00
# 23       27.01.2013               0       25     2607      279.00
# 24       29.01.2013               0       25     2607      279.00
# 25       27.01.2013               0       25     2609     1699.00
# 26       06.01.2013               0       25     2548     1708.95
# 27       26.01.2013               0       25     2611      299.00
# 28       02.01.2013               0       25     2546      299.00
# 29       06.01.2013               0       25     2515     1649.00
# ...             ...             ...      ...      ...         ...
# 2935819  16.10.2015              33       25     7789     1799.00
# 2935820  22.10.2015              33       25     7790      799.00
# 2935821  22.10.2015              33       25     7791      899.50
# 2935822  17.10.2015              33       25     7632     2310.00
# 2935823  26.10.2015              33       25     7487      299.00
# 2935824  14.10.2015              33       25     7029      999.00
# 2935825  23.10.2015              33       25     7460      299.00
# 2935826  04.10.2015              33       25     7233      599.00
# 2935827  18.10.2015              33       25     7308      349.00
# 2935828  21.10.2015              33       25     7233      479.00
# 2935829  03.10.2015              33       25     7233      599.00
# 2935830  11.10.2015              33       25     7286      299.00
# 2935831  22.10.2015              33       25     7187      299.00
# 2935832  26.10.2015              33       25     7484      299.00
# 2935833  22.10.2015              33       25     7308      349.00
# 2935834  29.10.2015              33       25     7235      298.00
# 2935835  18.10.2015              33       25     7327      349.00
# 2935836  22.10.2015              33       25     7327      349.00
# 2935837  24.10.2015              33       25     7328      249.00
# 2935838  17.10.2015              33       25     7338      349.00
# 2935839  24.10.2015              33       25     7315      399.00
# 2935840  31.10.2015              33       25     7409      299.00
# 2935841  11.10.2015              33       25     7393      349.00
# 2935842  10.10.2015              33       25     7384      749.00
# 2935843  09.10.2015              33       25     7409      299.00
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day                                          item_name  \
# 0                 1.0                                  ЯВЛЕНИЕ 2012 (BD)
# 1                 1.0           DEEP PURPLE  The House Of Blue Light  LP
# 2                -1.0           DEEP PURPLE  The House Of Blue Light  LP
# 3                 1.0           DEEP PURPLE  Who Do You Think We Are  LP
# 4                 1.0            DEEP PURPLE 30 Very Best Of 2CD (Фирм.)
# 5                 1.0  DEEP PURPLE Perihelion: Live In Concert DVD (К...
# 6                 1.0                   DEEP PURPLE Stormbringer (фирм.)
# 7                 1.0                             DEFTONES  Koi No Yokan
# 8                 1.0                             DEFTONES  Koi No Yokan
# 9                 3.0                          DEL REY LANA  Born To Die
# 10                2.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 11                1.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 12                1.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 13                2.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 14                1.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 15                2.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 16                1.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 17                1.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 18                1.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 19                1.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 20                1.0                 DEPECHE MODE  Music For The Masses
# 21                1.0               DEPECHE MODE  Sounds Of The Universe
# 22                1.0               DEPECHE MODE  Sounds Of The Universe
# 23                1.0                       DEPECHE MODE  The Best Of  1
# 24                1.0                       DEPECHE MODE  The Best Of  1
# 25                1.0  DEPECHE MODE  Tour Of The Universe  Barselona ...
# 26                1.0                      DEEP PURPLE  Stormbringer  LP
# 27                1.0  DEPECHE MODE  Tour Of The Universe  Barselona ...
# 28                1.0       DEEP PURPLE  Smoke On The Water  The Best Of
# 29                1.0  DEEP PURPLE  Come Taste The Band  Original Rec...
# ...               ...                                                ...
# 2935819           1.0   Watch_Dogs (Classics) [Xbox 360, русская версия]
# 2935820           1.0                    Watch_Dogs [PC, русская версия]
# 2935821           1.0                   Watch_Dogs [PS3, русская версия]
# 2935822           1.0  WARHAMMER ACCESSORIES: Space Marine Paint Set ...
# 2935823           1.0                V/A Trance Drive  3  2CD (digipack)
# 2935824           1.0  Tom Clancy's Ghost Recon: Future Soldier (Esse...
# 2935825           1.0             V/A The Golden Jazz Collection  1  2CD
# 2935826           1.0  Universal: Кабель HDMI Hori высокоскоростной, ...
# 2935827           1.0     V/A Clubber`s Mood Of Ibiza  3  2CD (digipack)
# 2935828           1.0  Universal: Кабель HDMI Hori высокоскоростной, ...
# 2935829           1.0  Universal: Кабель HDMI Hori высокоскоростной, ...
# 2935830           1.0                   V/A Caf? Du Soleil  1 (digipack)
# 2935831           1.0                               URIAH HEEP  Outsider
# 2935832           1.0  V/A Trance Collection  Танцевальный рай (mp3-C...
# 2935833           1.0     V/A Clubber`s Mood Of Ibiza  3  2CD (digipack)
# 2935834           1.0  Universal: Кабель оптический Gioteck XC-6 цифр...
# 2935835           1.0                 V/A Deep Calm Mood  2CD (digipack)
# 2935836           1.0                 V/A Deep Calm Mood  2CD (digipack)
# 2935837           1.0       V/A Deep House  Collection  Танцевальный рай
# 2935838           1.0          V/A Deep House  Series  7  2CD (digipack)
# 2935839           1.0                    V/A Dance Kick!  2CD (digipack)
# 2935840           1.0                   V/A Nu Jazz Selection (digipack)
# 2935841           1.0              V/A Lounge Del Mar  3  2CD (digipack)
# 2935842           1.0                     V/A Ladies Sing The Blues  3CD
# 2935843           1.0                   V/A Nu Jazz Selection (digipack)
# 2935844           1.0                   V/A Nu Jazz Selection (digipack)
# 2935845           1.0             V/A The Golden Jazz Collection  1  2CD
# 2935846           1.0                       V/A The Best Of The 3 Tenors
# 2935847           1.0  V/A Relax Collection  Planet MP3 (mp3-CD) (jewel)
# 2935848           1.0             V/A The Golden Jazz Collection  1  2CD
#
#          item_category_id  total_cat_cnt  min_cat_cnt       ...        \
# 0                      37       203284.0         -3.0       ...
# 1                      58        13631.0         -1.0       ...
# 2                      58        13631.0         -1.0       ...
# 3                      58        13631.0         -1.0       ...
# 4                      56         8281.0         -1.0       ...
# 5                      59         6611.0         -1.0       ...
# 6                      56         8281.0         -1.0       ...
# 7                      55       348591.0         -2.0       ...
# 8                      55       348591.0         -2.0       ...
# 9                      55       348591.0         -2.0       ...
# 10                     55       348591.0         -2.0       ...
# 11                     55       348591.0         -2.0       ...
# 12                     55       348591.0         -2.0       ...
# 13                     55       348591.0         -2.0       ...
# 14                     55       348591.0         -2.0       ...
# 15                     55       348591.0         -2.0       ...
# 16                     55       348591.0         -2.0       ...
# 17                     55       348591.0         -2.0       ...
# 18                     55       348591.0         -2.0       ...
# 19                     55       348591.0         -2.0       ...
# 20                     55       348591.0         -2.0       ...
# 21                     55       348591.0         -2.0       ...
# 22                     55       348591.0         -2.0       ...
# 23                     55       348591.0         -2.0       ...
# 24                     55       348591.0         -2.0       ...
# 25                     59         6611.0         -1.0       ...
# 26                     58        13631.0         -1.0       ...
# 27                     59         6611.0         -1.0       ...
# 28                     55       348591.0         -2.0       ...
# 29                     58        13631.0         -1.0       ...
# ...                   ...            ...          ...       ...
# 2935819                23       169944.0         -4.0       ...
# 2935820                30       456540.0         -3.0       ...
# 2935821                19       254887.0         -6.0       ...
# 2935822                64        39357.0         -1.0       ...
# 2935823                55       348591.0         -2.0       ...
# 2935824                19       254887.0         -6.0       ...
# 2935825                55       348591.0         -2.0       ...
# 2935826                 3        29807.0         -2.0       ...
# 2935827                55       348591.0         -2.0       ...
# 2935828                 3        29807.0         -2.0       ...
# 2935829                 3        29807.0         -2.0       ...
# 2935830                55       348591.0         -2.0       ...
# 2935831                55       348591.0         -2.0       ...
# 2935832                57        32683.0         -1.0       ...
# 2935833                55       348591.0         -2.0       ...
# 2935834                 3        29807.0         -2.0       ...
# 2935835                55       348591.0         -2.0       ...
# 2935836                55       348591.0         -2.0       ...
# 2935837                55       348591.0         -2.0       ...
# 2935838                55       348591.0         -2.0       ...
# 2935839                55       348591.0         -2.0       ...
# 2935840                55       348591.0         -2.0       ...
# 2935841                55       348591.0         -2.0       ...
# 2935842                55       348591.0         -2.0       ...
# 2935843                55       348591.0         -2.0       ...
# 2935844                55       348591.0         -2.0       ...
# 2935845                55       348591.0         -2.0       ...
# 2935846                55       348591.0         -2.0       ...
# 2935847                57        32683.0         -1.0       ...
# 2935848                55       348591.0         -2.0       ...
#
#          std_cat_price  total_shop_cnt  min_shop_cnt  max_shop_cnt  \
# 0           299.681484         46256.0          -1.0         100.0
# 1          1051.678052         81734.0          -2.0          44.0
# 2          1051.678052         81734.0          -2.0          44.0
# 3          1051.678052         81734.0          -2.0          44.0
# 4           550.847877         78079.0          -2.0          58.0
# 5           378.836804         48993.0          -2.0          80.0
# 6           550.847877         78079.0          -2.0          58.0
# 7           113.765602         63388.0          -1.0         637.0
# 8           113.765602         63388.0          -1.0         637.0
# 9           113.765602         63388.0          -1.0         637.0
# 10          113.765602         63388.0          -1.0         637.0
# 11          113.765602         63388.0          -1.0         637.0
# 12          113.765602         63388.0          -1.0         637.0
# 13          113.765602         63388.0          -1.0         637.0
# 14          113.765602         63388.0          -1.0         637.0
# 15          113.765602         63388.0          -1.0         637.0
# 16          113.765602         63388.0          -1.0         637.0
# 17          113.765602         63388.0          -1.0         637.0
# 18          113.765602         63388.0          -1.0         637.0
# 19          113.765602         63388.0          -1.0         637.0
# 20          113.765602         63388.0          -1.0         637.0
# 21          113.765602         63388.0          -1.0         637.0
# 22          113.765602         63388.0          -1.0         637.0
# 23          113.765602         63388.0          -1.0         637.0
# 24          113.765602         63388.0          -1.0         637.0
# 25          378.836804         48993.0          -2.0          80.0
# 26         1051.678052         81734.0          -2.0          44.0
# 27          378.836804         48993.0          -2.0          80.0
# 28          113.765602         63388.0          -1.0         637.0
# 29         1051.678052         81734.0          -2.0          44.0
# ...                ...             ...           ...           ...
# 2935819     793.321343          7705.0          -1.0          23.0
# 2935820     346.719389         60828.0          -2.0         100.0
# 2935821     798.465332         73455.0          -2.0         103.0
# 2935822     610.777401             NaN           NaN           NaN
# 2935823     113.765602         63388.0          -1.0         637.0
# 2935824     798.465332         73455.0          -2.0         103.0
# 2935825     113.765602         63388.0          -1.0         637.0
# 2935826    1435.229478         28355.0          -2.0          83.0
# 2935827     113.765602         63388.0          -1.0         637.0
# 2935828    1435.229478         28355.0          -2.0          83.0
# 2935829    1435.229478         28355.0          -2.0          83.0
# 2935830     113.765602         63388.0          -1.0         637.0
# 2935831     113.765602         63388.0          -1.0         637.0
# 2935832      76.398986        141107.0          -2.0          98.0
# 2935833     113.765602         63388.0          -1.0         637.0
# 2935834    1435.229478         28355.0          -2.0          83.0
# 2935835     113.765602         63388.0          -1.0         637.0
# 2935836     113.765602         63388.0          -1.0         637.0
# 2935837     113.765602         63388.0          -1.0         637.0
# 2935838     113.765602         63388.0          -1.0         637.0
# 2935839     113.765602         63388.0          -1.0         637.0
# 2935840     113.765602         63388.0          -1.0         637.0
# 2935841     113.765602         63388.0          -1.0         637.0
# 2935842     113.765602         63388.0          -1.0         637.0
# 2935843     113.765602         63388.0          -1.0         637.0
# 2935844     113.765602         63388.0          -1.0         637.0
# 2935845     113.765602         63388.0          -1.0         637.0
# 2935846     113.765602         63388.0          -1.0         637.0
# 2935847      76.398986        141107.0          -2.0          98.0
# 2935848     113.765602         63388.0          -1.0         637.0
#
#          mean_shop_cnt  std_shop_cnt  min_shop_price  max_shop_price  \
# 0             1.166961      1.149310            0.10         32990.0
# 1             1.144077      0.752636            0.07         32990.0
# 2             1.144077      0.752636            0.07         32990.0
# 3             1.144077      0.752636            0.07         32990.0
# 4             1.122260      0.802511            0.10         32990.0
# 5             1.163508      1.026188            0.10         32997.5
# 6             1.122260      0.802511            0.10         32990.0
# 7             1.823118      8.002811            4.00         27900.0
# 8             1.823118      8.002811            4.00         27900.0
# 9             1.823118      8.002811            4.00         27900.0
# 10            1.823118      8.002811            4.00         27900.0
# 11            1.823118      8.002811            4.00         27900.0
# 12            1.823118      8.002811            4.00         27900.0
# 13            1.823118      8.002811            4.00         27900.0
# 14            1.823118      8.002811            4.00         27900.0
# 15            1.823118      8.002811            4.00         27900.0
# 16            1.823118      8.002811            4.00         27900.0
# 17            1.823118      8.002811            4.00         27900.0
# 18            1.823118      8.002811            4.00         27900.0
# 19            1.823118      8.002811            4.00         27900.0
# 20            1.823118      8.002811            4.00         27900.0
# 21            1.823118      8.002811            4.00         27900.0
# 22            1.823118      8.002811            4.00         27900.0
# 23            1.823118      8.002811            4.00         27900.0
# 24            1.823118      8.002811            4.00         27900.0
# 25            1.163508      1.026188            0.10         32997.5
# 26            1.144077      0.752636            0.07         32990.0
# 27            1.163508      1.026188            0.10         32997.5
# 28            1.823118      8.002811            4.00         27900.0
# 29            1.144077      0.752636            0.07         32990.0
# ...                ...           ...             ...             ...
# 2935819       1.106563      0.604841           14.00         15990.0
# 2935820       1.195989      1.181002            0.10         31990.0
# 2935821       1.149333      1.058031            0.10         35490.0
# 2935822            NaN           NaN             NaN             NaN
# 2935823       1.823118      8.002811            4.00         27900.0
# 2935824       1.149333      1.058031            0.10         35490.0
# 2935825       1.823118      8.002811            4.00         27900.0
# 2935826       1.110567      0.991501            0.10         42990.0
# 2935827       1.823118      8.002811            4.00         27900.0
# 2935828       1.110567      0.991501            0.10         42990.0
# 2935829       1.110567      0.991501            0.10         42990.0
# 2935830       1.823118      8.002811            4.00         27900.0
# 2935831       1.823118      8.002811            4.00         27900.0
# 2935832       1.201647      1.108850            0.10         34990.0
# 2935833       1.823118      8.002811            4.00         27900.0
# 2935834       1.110567      0.991501            0.10         42990.0
# 2935835       1.823118      8.002811            4.00         27900.0
# 2935836       1.823118      8.002811            4.00         27900.0
# 2935837       1.823118      8.002811            4.00         27900.0
# 2935838       1.823118      8.002811            4.00         27900.0
# 2935839       1.823118      8.002811            4.00         27900.0
# 2935840       1.823118      8.002811            4.00         27900.0
# 2935841       1.823118      8.002811            4.00         27900.0
# 2935842       1.823118      8.002811            4.00         27900.0
# 2935843       1.823118      8.002811            4.00         27900.0
# 2935844       1.823118      8.002811            4.00         27900.0
# 2935845       1.823118      8.002811            4.00         27900.0
# 2935846       1.823118      8.002811            4.00         27900.0
# 2935847       1.201647      1.108850            0.10         34990.0
# 2935848       1.823118      8.002811            4.00         27900.0
#
#          mean_shop_price  std_shop_price
# 0             942.244232     1906.464127
# 1             818.345743     1711.236198
# 2             818.345743     1711.236198
# 3             818.345743     1711.236198
# 4             743.052339     1544.768269
# 5             884.981227     1815.446620
# 6             743.052339     1544.768269
# 7             607.893809      833.904686
# 8             607.893809      833.904686
# 9             607.893809      833.904686
# 10            607.893809      833.904686
# 11            607.893809      833.904686
# 12            607.893809      833.904686
# 13            607.893809      833.904686
# 14            607.893809      833.904686
# 15            607.893809      833.904686
# 16            607.893809      833.904686
# 17            607.893809      833.904686
# 18            607.893809      833.904686
# 19            607.893809      833.904686
# 20            607.893809      833.904686
# 21            607.893809      833.904686
# 22            607.893809      833.904686
# 23            607.893809      833.904686
# 24            607.893809      833.904686
# 25            884.981227     1815.446620
# 26            818.345743     1711.236198
# 27            884.981227     1815.446620
# 28            607.893809      833.904686
# 29            818.345743     1711.236198
# ...                  ...             ...
# 2935819       721.404832     1090.542421
# 2935820       764.037021     1423.403039
# 2935821       849.650302     1648.627772
# 2935822              NaN             NaN
# 2935823       607.893809      833.904686
# 2935824       849.650302     1648.627772
# 2935825       607.893809      833.904686
# 2935826      1036.840634     1828.560756
# 2935827       607.893809      833.904686
# 2935828      1036.840634     1828.560756
# 2935829      1036.840634     1828.560756
# 2935830       607.893809      833.904686
# 2935831       607.893809      833.904686
# 2935832       777.627253     1611.771491
# 2935833       607.893809      833.904686
# 2935834      1036.840634     1828.560756
# 2935835       607.893809      833.904686
# 2935836       607.893809      833.904686
# 2935837       607.893809      833.904686
# 2935838       607.893809      833.904686
# 2935839       607.893809      833.904686
# 2935840       607.893809      833.904686
# 2935841       607.893809      833.904686
# 2935842       607.893809      833.904686
# 2935843       607.893809      833.904686
# 2935844       607.893809      833.904686
# 2935845       607.893809      833.904686
# 2935846       607.893809      833.904686
# 2935847       777.627253     1611.771491
# 2935848       607.893809      833.904686
#
# [2935849 rows x 26 columns]

# %%
## Save
sale_train_extended.to_csv("data/sales_train_v2_fv2.csv", index=None)

# %%
test_extended.to_csv("data/test_fv2.csv", index=None)

# %%
sale_train_extended.columns
# Out:
# Index([u'date', u'date_block_num', u'shop_id', u'item_id', u'item_price',
#        u'item_cnt_day', u'item_name', u'item_category_id', u'total_cat_cnt',
#        u'min_cat_cnt', u'max_cat_cnt', u'mean_cat_cnt', u'std_cat_cnt',
#        u'min_cat_price', u'max_cat_price', u'mean_cat_price', u'std_cat_price',
#        u'total_shop_cnt', u'min_shop_cnt', u'max_shop_cnt', u'mean_shop_cnt',
#        u'std_shop_cnt', u'min_shop_price', u'max_shop_price',
#        u'mean_shop_price', u'std_shop_price'],
#       dtype='object')
